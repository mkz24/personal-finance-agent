# %% [markdown]
# # 💰 Personal Finance Agent
# This notebook clones your GitHub repo and runs the Personal Finance Agent app using Streamlit + ngrok inside Google Colab.

# %% [markdown]
# ## Step 1: Clone the Repository

# %%
# !git clone https://github.com/mkz24/personal-finance-agent.git
# %cd personal-finance-agent

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Step 3: Set Your Google Gemini API Key
# Replace `YOUR_GEMINI_API_KEY` below with your actual key from [Google AI Studio](https://aistudio.google.com/app/apikey).

# %%
import os
os.environ['GOOGLE_API_KEY'] = 'YOUR_GEMINI_API_KEY'  # 🔑 Replace this!

# %% [markdown]
# ## Step 4: Set Up ngrok (Public URL for Streamlit)
# Get a free ngrok auth token at [ngrok.com](https://dashboard.ngrok.com/get-started/your-authtoken) and paste it below.

# %%
from pyngrok import ngrok

ngrok.set_auth_token('YOUR_NGROK_AUTH_TOKEN')  # 🔑 Replace this!

public_url = ngrok.connect(8501)
print('🌐 Your app is live at:', public_url)

# %% [markdown]
# ## Step 5: Run the App
# Click the ngrok link printed above to open your app in the browser!

# %%
# !streamlit run app.py &
